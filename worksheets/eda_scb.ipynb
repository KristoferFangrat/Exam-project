# %%
import requests
import json

lat = 59.402181
lon = 13.511498


historical_api_url = f"https://archive-api.open-meteo.com/v1/archive?latitude={lat}&longitude={lon}&start_date=2024-10-03&end_date=2024-10-05&hourly=temperature_2m,precipitation&timezone=auto"

# Hämta data från API
response = requests.get(historical_api_url)

# Kontrollera om förfrågan var framgångsrik
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4))  # Skriv ut data i läsbart format

    # Kontrollera vilka nycklar som finns i datan
    if 'hourly' in data:
        # Exempel på hur du kan extrahera specifik information från data
        for entry in data['hourly']['time']:
            date = entry
            temperature = data['hourly']['temperature_2m'][data['hourly']['time'].index(entry)]
            print(f"Date: {date}, Temperature: {temperature}")
    else:
        print("Nyckeln 'hourly' finns inte i datan.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# {
#     "latitude": 59.36731,
#     "longitude": 13.5,
#     "generationtime_ms": 0.05805492401123047,
#     "utc_offset_seconds": 3600,
#     "timezone": "Europe/Stockholm",
#     "timezone_abbreviation": "CET",
#     "elevation": 49.0,
#     "hourly_units": {
#         "time": "iso8601",
#         "temperature_2m": "\u00b0C",
#         "precipitation": "mm"
#     },
#     "hourly": {
#         "time": [
#             "2024-10-03T00:00",
#             "2024-10-03T01:00",
#             "2024-10-03T02:00",
#             "2024-10-03T03:00",
#             "2024-10-03T04:00",
#             "2024-10-03T05:00",
#             "2024-10-03T06:00",
#             "2024-10-03T07:00",
#             "2024-10-03T08:00",
#             "2024-10-03T09:00",
#             "2024-10-03T10:00",
#             "2024-10-03T11:00",
#             "2024-10-03T12:00",
#             "2024-10-03T13:00",
#             "2024-10-03T14:00",
#             "2024-10-03T15:00",
#             "2024-10-03T16:00",
# ...
